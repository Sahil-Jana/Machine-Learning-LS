# %%
# !nvidia-smi
# Out:
# Fri Jul 12 10:23:16 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()
from IPython.display import display, Image

import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ColabNotebooks
# Out:
# /content/drive/MyDrive/ColabNotebooks

# %%
# !ls
# Out:
#  car   data.yaml  'YOLO assignment.ipynb'   yolov8n.pt	 yolov8s.pt

# %%
# !yolo mode=train model=yolov8s.pt data=data.yaml epochs=50 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/drive/MyDrive/ColabNotebooks/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/drive/MyDrive/ColabNotebooks/runs/detect/train/results.png', width=600)

# %%
# !yolo mode=predict model=/content/drive/MyDrive/ColabNotebooks/runs/detect/train/weights/best.pt conf=0.5 source=/content/drive/MyDrive/ColabNotebooks/car/test/images save=true
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11131776 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/22 /content/drive/MyDrive/ColabNotebooks/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 640x640 1 license_plate, 16.4ms
# image 2/22 /content/drive/MyDrive/ColabNotebooks/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 640x640 1 car, 1 license_plate, 16.5ms
# image 3/22 /content/drive/MyDrive/ColabNotebooks/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 640x640 3 cars, 2 license_plates, 16.4ms
# image 4/22 /content/drive/MyDrive/ColabNotebooks/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 640x640 1 front_grill, 2 headlamps, 1 license_plate, 16.4ms
# ...
